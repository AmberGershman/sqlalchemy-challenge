# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy 
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect, distinct, join

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
base = automap_base()
base.prepare(engine, reflect = True)
# reflect the tables
base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# We can view all of the classes that automap found
print(base.classes.station.__table__.columns.keys())
print(base.classes.measurement.__table__.columns.keys())
# Out:
# ['id', 'station', 'name', 'latitude', 'longitude', 'elevation']
# ['id', 'station', 'date', 'prcp', 'tobs']

# %%
# Save references to each table
measurements = base.classes.measurement
stations = base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results
test = session.query(measurements, measurements.date, measurements.prcp).order_by(measurements.date.desc()).first()
print(test)
# Calculate the date 1 year ago from the last data point in the database
one_year_ago = dt.date(2017, 8, 23) - dt.timedelta(days=365)
print(one_year_ago)
# Perform a query to retrieve the data and precipitation scores
prcp_2017 = session.query(measurements.date, measurements.prcp)\
                        .order_by(measurements.date.desc())\
                        .filter(measurements.date > one_year_ago).all()
# Save the query results as a Pandas DataFrame and set the index to the date column
precipitation_df = pd.DataFrame(prcp_2017)
precipitation_df = precipitation_df.set_index('date')
precipitation_df

# Sort the dataframe by date
precipitation_df = precipitation_df.sort_values('date').rename(columns={"prcp": "Precipitation"})
precipitation_df

# Use Pandas Plotting with Matplotlib to plot the data
precipitation_df.plot(kind="area", figsize=(13, 8))
plt.xticks(rotation='vertical')
plt.xlabel("Date")
plt.ylabel("Precipitation (in inches)");
# Out:
# (<sqlalchemy.ext.automap.measurement object at 0x000002B1E7862488>, '2017-08-23', 0.0)
# 2016-08-23

# %% [markdown]
# # Exploratory Climate Analysis

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
sum_stats = round(precipitation_df["Precipitation"].describe(), 3)
sum_stats = pd.DataFrame(sum_stats)
sum_stats
# Out:
#        Precipitation
# count       2015.000
# mean           0.176
# std            0.460
# min            0.000
# 25%            0.000
# 50%            0.020
# 75%            0.130
# max            6.700

# %%
# Design a query to show how many stations are available in this dataset?
station_count = session.query(stations.name)\
.group_by(stations.name).all()
print(f"Total stations in Dataset: {len(station_count)}")
for station in station_count:
    print(f" This includes station:{station} ")
# Out:
# Total stations in Dataset: 9
#  This includes station:('HONOLULU OBSERVATORY 702.2, HI US',)
#  This includes station:('KANEOHE 838.1, HI US',)
#  This includes station:('KUALOA RANCH HEADQUARTERS 886.9, HI US',)
#  This includes station:('MANOA LYON ARBO 785.2, HI US',)
#  This includes station:('PEARL CITY, HI US',)
#  This includes station:('UPPER WAHIAWA 874.3, HI US',)
#  This includes station:('WAIHEE 837.5, HI US',)
#  This includes station:('WAIKIKI 717.2, HI US',)
#  This includes station:('WAIMANALO EXPERIMENTAL FARM, HI US',)

# %%
# What are the most active stations? (i.e. what stations have the most rows)?
# List the stations and the counts in descending order.
active_stations = session.query(measurements.station, func.count(measurements.station))\
.group_by(measurements.station)\
.order_by(func.count(measurements.station).desc()).all()
for station in active_stations:
    print(f"Station {station[0]} has recorded {station[1]} measurements")
# Out:
# Station USC00519281 has recorded 2772 measurements
# Station USC00519397 has recorded 2724 measurements
# Station USC00513117 has recorded 2709 measurements
# Station USC00519523 has recorded 2669 measurements
# Station USC00516128 has recorded 2612 measurements
# Station USC00514830 has recorded 2202 measurements
# Station USC00511918 has recorded 1979 measurements
# Station USC00517948 has recorded 1372 measurements
# Station USC00518838 has recorded 511 measurements

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature of the most active station?
temps = session.query(measurements.station, func.max(measurements.tobs), func.min(measurements.tobs), func.avg(measurements.tobs))\
.group_by(measurements.station)\
.order_by(func.count(measurements.station).desc()).all()
temps
# Out:
# [('USC00519281', 85.0, 54.0, 71.66378066378067),
#  ('USC00519397', 87.0, 56.0, 74.55323054331865),
#  ('USC00513117', 85.0, 59.0, 72.68918420081211),
#  ('USC00519523', 85.0, 56.0, 74.5436493068565),
#  ('USC00516128', 84.0, 58.0, 70.91500765696784),
#  ('USC00514830', 85.0, 58.0, 74.8732970027248),
#  ('USC00511918', 87.0, 53.0, 71.61596766043456),
#  ('USC00517948', 87.0, 58.0, 74.68440233236151),
#  ('USC00518838', 83.0, 58.0, 72.72407045009784)]

# %%
# Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
hottest_station = session.query(measurements.station)\
.group_by(measurements.station)\
.order_by(func.count(measurements.tobs).desc()).first()
hottest_station = hottest_station[0]
hottest_station
# Out:
# 'USC00519281'

# %%
hottest_year = session.query(measurements.date, measurements.tobs).filter(measurements.station==hottest_station, measurements.date>one_year_ago).all()
hottest_year
# Out:
# [('2016-08-24', 77.0),
#  ('2016-08-25', 80.0),
#  ('2016-08-26', 80.0),
#  ('2016-08-27', 75.0),
#  ('2016-08-28', 73.0),
#  ('2016-08-29', 78.0),
#  ('2016-08-30', 77.0),
#  ('2016-08-31', 78.0),
#  ('2016-09-01', 80.0),
#  ('2016-09-02', 80.0),
#  ('2016-09-03', 78.0),
#  ('2016-09-04', 78.0),
#  ('2016-09-05', 78.0),
#  ('2016-09-06', 73.0),
#  ('2016-09-07', 74.0),
#  ('2016-09-08', 80.0),
#  ('2016-09-09', 79.0),
#  ('2016-09-10', 77.0),
#  ('2016-09-11', 80.0),
#  ('2016-09-12', 76.0),
#  ('2016-09-13', 79.0),
#  ('2016-09-14', 75.0),
#  ('2016-09-15', 79.0),
#  ('2016-09-16', 78.0),
#  ('2016-09-17', 79.0),
#  ('2016-09-18', 78.0),
#  ('2016-09-19', 78.0),
#  ('2016-09-20', 76.0),
#  ('2016-09-21', 74.0),
#  ('2016-09-22', 77.0),
#  ('2016-09-23', 78.0),
#  ('2016-09-24', 79.0),
#  ('2016-09-25', 79.0),
#  ('2016-09-26', 77.0),
#  ('2016-09-27', 80.0),
#  ('2016-09-28', 78.0),
#  ('2016-09-29', 78.0),
#  ('2016-09-30', 78.0),
#  ('2016-10-01', 77.0),
#  ('2016-10-02', 79.0),
# ...

# %%
hottest_year=pd.DataFrame(hottest_year).rename(columns={"tobs": "Temperature"})
hottest_year.plot(kind="hist", figsize=(10, 8))
plt.xlabel("Degrees")
plt.title(f"2016-2017 Temperatures in {hottest_station}");

# %% [markdown]
# ## Bonus Challenge Assignment

# %%
# This function called `calc_temps` will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(measurements.tobs), func.avg(measurements.tobs), func.max(measurements.tobs)).\
        filter(measurements.date >= start_date).filter(measurements.date <= end_date).all()

# function usage example
print(calc_temps('2012-02-28', '2012-03-05'))
# Out:
# [(62.0, 69.57142857142857, 74.0)]

# %%
# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.
trip_temps = calc_temps('2017-02-28', '2017-03-05')
trip_temps
# Out:
# [(64.0, 72.02777777777777, 78.0)]

# %%
# Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr)

x = range(len(trip_temps))
plt.boxplot(trip_temps, patch_artist=True)
plt.title('Trip Avg Temp')
plt.xlabel("Temperatures")
plt.show()

# %%
with plt.xkcd():
    fig, ax = plt.subplots()
    x = range(len(trip_temps))
    ax.boxplot(trip_temps, patch_artist=True)
    ax.set_facecolor('xkcd:coral')
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.set_title('Fun Avg Temp')
    plt.show()

# %%
# Calculate the total amount of rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation

# %%
# Create a query that will calculate the daily normals 
# (i.e. the averages for tmin, tmax, and tavg for all historic data matching a specific month and day)

def daily_normals(date):
    """Daily Normals.
    
    Args:
        date (str): A date string in the format '%m-%d'
        
    Returns:
        A list of tuples containing the daily normals, tmin, tavg, and tmax
    
    """
    
    sel = [func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    return session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) == date).all()
    
daily_normals("01-01")

# %%
# calculate the daily normals for your trip
# push each tuple of calculations into a list called `normals`

# Set the start and end date of the trip

# Use the start and end date to create a range of dates

# Stip off the year and save a list of %m-%d strings

# Loop through the list of %m-%d strings and calculate the normals for each date

# %%
# Load the previous query results into a Pandas DataFrame and add the `trip_dates` range as the `date` index

# %%
# Plot the daily normals as an area plot with `stacked=False`
